# %%
import numpy as np

# %%
riko = np.genfromtxt('/Users/moriwakiryou/Documents/riko2.txt', dtype = None, delimiter = "\t")
print(riko)
# Out:
# b'$GPGSV,3,1,11,24,57,036,31,10,50,311,35,12,46,130,17,15,33,091,35*76 $GPGSV,3,2,11,25,29,175,29,$GPGGA,081624.000,3350.9021,N,13246.2080,E,1,6,1.17,35.0,M,29.6,M,,*68 $GPGSA,A,3,10,25,15,24,12,18,,,,,,,1.51,1.17,0.97*00 $GPGSV,3,1,11,24,57,036,31,10,50,311,35,12,46,130,19,15,33,091,35*78 $GPGSV,3,2,11,25,29,175,29,32,23,298,17,18,16,211,23,13,02,089,*75 $GPGSV,3,3,11,22,02,285,,193,,,,43,,,*78 $GPRMC,081624.000,A,3350.9021,N,13246.2080,E,0.00,40.55,130922,,,A*5F $GPGGA,081625.000,3350.9021,N,13246.2080,E,1,6,1.17,35.0,M,29.6,M,,*69 $GPGSA,A,3,10,25,15,24,12,18,,,,,,,1.51,1.17,0.97*00 $GPGSV,3,1,11,24,57,036,.17,0.96*01 $GPGSV,3,1,11,24,57,036,30,10,50,311,34,12,46,130,19,15,33,091,34*79 $GPGSV,3,2,11,25,29,175,29,32,23,298,17,18,16,211,21,13,02,089,*77 $GPGSV,3,3,11,22,02,285,,193,,,,46,,,*7D $GPRMC,081635.000,A,3350.9021,N,13246.2080,E,0.00,40.55,130922,,,A*5F $GPGGA,081636.000,3350.9021,N,13246.2080,E,1,6,1.17,35.0,M,29.6,M,,*6B $GPGSA,A,3,10,25,15,24,12,18,,,,,,,1.51,1.17,0.96*0
# ...

# %%
# Out:
# ['$GPGSV,3,1,11,24,57,036,31,10,50,311,35,12,46,130,17,15,33,091,35*76 $GPGSV,3,2,11,25,29,175,29,$GPGGA,081624.000,3350.9021,N,13246.2080,E,1,6,1.17,35.0,M,29.6,M,,*68 $GPGSA,A,3,10,25,15,24,12,18,,,,,,,1.51,1.17,0.97*00 $GPGSV,3,1,11,24,57,036,31,10,50,311,35,12,46,130,19,15,33,091,35*78 $GPGSV,3,2,11,25,29,175,29,32,23,298,17,18,16,211,23,13,02,089,*75 $GPGSV,3,3,11,22,02,285,,193,,,,43,,,*78 $GPRMC,081624.000,A,3350.9021,N,13246.2080,E,0.00,40.55,130922,,,A*5F $GPGGA,081625.000,3350.9021,N,13246.2080,E,1,6,1.17,35.0,M,29.6,M,,*69 $GPGSA,A,3,10,25,15,24,12,18,,,,,,,1.51,1.17,0.97*00 $GPGSV,3,1,11,24,57,036,.17,0.96*01 $GPGSV,3,1,11,24,57,036,30,10,50,311,34,12,46,130,19,15,33,091,34*79 $GPGSV,3,2,11,25,29,175,29,32,23,298,17,18,16,211,21,13,02,089,*77 $GPGSV,3,3,11,22,02,285,,193,,,,46,,,*7D $GPRMC,081635.000,A,3350.9021,N,13246.2080,E,0.00,40.55,130922,,,A*5F $GPGGA,081636.000,3350.9021,N,13246.2080,E,1,6,1.17,35.0,M,29.6,M,,*6B $GPGSA,A,3,10,25,15,24,12,18,,,,,,,1.51,1.17,0.96*0
# ...

# %%
with open('/Users/moriwakiryou/Documents/riko2.txt') as f:
    for i, line in enumerate(f):
        if 'OVERFLOW' in line:
            break
print(i)
print(line)
# Out:
# 0
# ...
